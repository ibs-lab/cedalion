# %% [markdown]
# # Supplementary Material
#
# The paper is accompanied by seven Jupyter tutorial notebooks, included here in rendered form, along with a short Python primer for researchers new to the language.
#
# The notebooks can be explored interactively on Google Colab via the following links:
#
# - S0: Python Primer for fNIRS/DOT Researchers starting with Cedalion
# - [S1: Head models and Forward Modelling](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/1_heads_and_fwm.ipynb)
# - [S2: Photogrammetric Optode Co-Registration](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/2_photogrammetry.ipynb)
# - [S3: Signal Processing](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/3_signal_processing.ipynb)
# - [S4: Model-driven (GLM)](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/4_model_driven_analysis.ipynb)
# - [S5: DOT - Image Reconstruction](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/5_image_reconstruction.ipynb)
# - [S6: Data-Driven (ML) Analysis](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/6_data_driven_analysis.ipynb)
# - [S7: Data Augmentation](https://colab.research.google.com/github/ibs-lab/cedalion/blob/dev/examples/tutorial/7_data_augmentation.ipynb)
#
# Please use the PDF's document outline to navigate.
#
# The notebooks are hosted on GitHub and will eventually be available on Code Ocean:
#
#   - **Code Ocean**: *Link and DOI pending*
#   - **GitHub**: [https://github.com/ibs-lab/cedalion/tree/dev/examples/tutorial](https://github.com/ibs-lab/cedalion/tree/dev/examples/tutorial)
#
# To cite any of these notebooks please use the following:
#
#     FIXME DOI issued by Code Ocean
#
# The notebooks are also part of the Cedalion's official documentation, available at
#
#   [http://cedalion.tools/docs](http://cedalion.tools/docs)
